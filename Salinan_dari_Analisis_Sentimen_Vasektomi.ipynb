# %% [markdown]
# # Instalisasi

# %%
# !pip install Sastrawi tweet-preprocessor textblob wordcloud nltk
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.7/209.7 kB 3.6 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
import re
import seaborn as sns
import matplotlib.pyplot as plt
import Sastrawi
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory, StopWordRemover, ArrayDictionary
import preprocessor as p
from textblob import TextBlob
import nltk
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize

nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/Vasektomi.csv')
df.head()
# Out:
#    conversation_id_str                      created_at  favorite_count  \
# 0  1928601988524093707  Fri May 30 23:58:40 +0000 2025              22
# 1  1928356022952821115  Fri May 30 23:56:46 +0000 2025              11
# 2  1928428224771436975  Fri May 30 23:52:41 +0000 2025             329
# 3  1928600033991004447  Fri May 30 23:50:54 +0000 2025               1
# 4  1928356022952821115  Fri May 30 23:47:15 +0000 2025               2
#
#                                            full_text               id_str  \
# 0  Progresif : Jangan cuma cewek aja dong yang KB...  1928601988524093707
# 1  @Sukirman2019 @KangManto123 Vasektomi itu salu...  1928601510226571510
# 2  @indra_kencana bukan soal imbalan vasektominya...  1928600484157300970
# 3  Masih banyak yg kegocek dgn kalimat kaya gini....  1928600033991004447
# 4  @Sukirman2019 @KangManto123 Tapi kata dokter s...  1928599116445110481
#
#   image_url in_reply_to_screen_name lang  location  quote_count  reply_count  \
# ...

# %%
df = df[['full_text','favorite_count','created_at']]
df
# Out:
#                                              full_text  favorite_count  \
# 0    Progresif : Jangan cuma cewek aja dong yang KB...              22
# 1    @Sukirman2019 @KangManto123 Vasektomi itu salu...              11
# 2    @indra_kencana bukan soal imbalan vasektominya...             329
# 3    Masih banyak yg kegocek dgn kalimat kaya gini....               1
# 4    @Sukirman2019 @KangManto123 Tapi kata dokter s...               2
# ..                                                 ...             ...
# 448  Lagi rame soal vasektomi nihh Bener nggak sih ...               2
# 449  para lelaki ini hamil kaga tapi berasa punya h...               1
# 450  opini buruk. ini sama aja kaya si sender mengu...               0
# 451  Padahal kk nya cm bilang gamau hamil. Tp klo u...               0
# 452  @suikamargasatwa Ehm...alasannya supaya negara...               0
#
#                          created_at
# 0    Fri May 30 23:58:40 +0000 2025
# 1    Fri May 30 23:56:46 +0000 2025
# ...

# %% [markdown]
# # 3. Labeling

# %%
df = pd.read_csv('/content/drive/MyDrive/PrepocessingVasektomi.csv')
df
# Out:
#                                  normalisasi_stopwords
# 0    progresif jangan cuma cewek dong kb cowok haru...
# 1       vasektomi salur potong bukan burung potong kak
# 2    bukan soal imbal vasektomi kecil gratis biaya ...
# 3    banyak gocek kalimat kayak begini padahal kdm ...
# 4    kata dokter iring jalan waktu vas deference bu...
# ..                                                 ...
# 447  rame soal vasektomi benar sih vasektomi kebiri...
# 448  lelaki hamil kagak asa punya hak atas tubuh pe...
# 449  opini buruk sama kayak sender utara wenang di ...
# 450  padahal kakak cuma bilang hamil kalau suami is...
# 451  ehmalasannya negara alami demographic meltdown...
#
# [452 rows x 1 columns]

# %%
# !pip install tweet-preprocessor
# !pip install textblob
# !pip install wordcloud
# !pip install nltk

import preprocessor as p
from textblob import TextBlob
import nltk
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize

nltk.download('punkt')
# Out:
# ...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
data_tweet = list(df['normalisasi_stopwords'])
polaritas = 0

status = []
total_positif = total_negatif = total_netral = total = 0

for i, tweet in enumerate(data_tweet):
    analysis = TextBlob(tweet)
    polaritas += analysis.polarity

    if analysis.sentiment.polarity > 0.0:
        total_positif += 1
        status.append('Positif')
    elif analysis.sentiment.polarity == 0.0:
        total_netral += 1
        status.append('Netral')
    else:
        total_negatif += 1
        status.append('Negatif')

    total += 1

print(f'Hasil Analisis Data:\nPositif = {total_positif}\nNetral = {total_netral}\nNegatif = {total_negatif}')
print(f'\nTotal Data : {total}')
# Out:
# Hasil Analisis Data:
# Positif = 21
# Netral = 400
# Negatif = 31
#
# Total Data : 452

# %%
df['klasifikasi'] = status
df
# Out:
#                                  normalisasi_stopwords klasifikasi
# 0    progresif jangan cuma cewek dong kb cowok haru...      Netral
# 1       vasektomi salur potong bukan burung potong kak      Netral
# 2    bukan soal imbal vasektomi kecil gratis biaya ...      Netral
# 3    banyak gocek kalimat kayak begini padahal kdm ...      Netral
# 4    kata dokter iring jalan waktu vas deference bu...      Netral
# ..                                                 ...         ...
# 447  rame soal vasektomi benar sih vasektomi kebiri...      Netral
# 448  lelaki hamil kagak asa punya hak atas tubuh pe...      Netral
# 449  opini buruk sama kayak sender utara wenang di ...      Netral
# 450  padahal kakak cuma bilang hamil kalau suami is...     Negatif
# 451  ehmalasannya negara alami demographic meltdown...     Negatif
#
# [452 rows x 2 columns]
